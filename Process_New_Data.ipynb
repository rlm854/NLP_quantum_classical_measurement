# %%
import os
import pandas as pd

# %%
cwd = os.getcwd()
data_folder = cwd + '/foldername/'

# %%
#import the data
data_sources = pd.read_excel(data_folder + 'filename')
data_more_better = pd.read_excel(data_folder + 'filename')
data_generic = pd.read_excel(data_folder + 'filename')
data_twoStudents = pd.read_csv(data_folder + 'filename')

# %%
#save the cleaned data
data_folder = cwd + '/2025_data_cleaned/'
data_sources.to_excel(data_folder + "data_sources.xlsx")
data_more.to_excel(data_folder + "data_more.xlsx")
data_better.to_excel(data_folder + "data_better.xlsx")
data_classical.to_excel(data_folder + "data_classical.xlsx")
data_quantum.to_excel(data_folder + "data_quantum.xlsx")
data_twoStudents.to_excel(data_folder + "data_twoStudents.xlsx")
